# %% [markdown]
# La structure de donnée utilisée pour qtocker la base de donnée et celle de l'arbre, grâce au système de 'parent'.
#
# Cette structure est implémentée dans le module 'toolbox'.
#
# Celui-ci est utilisé par le module 'display_data' qui est directement calibré pour répondre au problème.

# %%
# Importation du module
from test_teamrise.display_data import Data_reader

# %%
# Lecture de la base de donnée
objectives = Data_reader('data/Test Dev- Dataset.xlsx')

# %% [markdown]
# Une fois la base de donnée lue et l'arbre constitué, on peut le représenté en ajoutant différents filtres.

# %%
# Représentation de l'arbre
objectives.display(team='all', level='all', minimum_progress='all')
